# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

df = pd.read_csv('ch6_cell28_dev_feat1_filtered.tsv',sep='\t')
features,label = df.drop(['name','population'],axis=1), df.iloc[:,-1]
feature_names = list(features.columns)
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.30, random_state=42)
rf_model = RandomForestRegressor()
rf_model.fit(X_train,y_train)
pred_y = rf_model.predict(X_test)
mse_score_old = mean_squared_error(y_test,pred_y)
print("MSE value of base model is",mse_score_old)

print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rf_model.feature_importances_),feature_names),reverse=True))
# Out:
# /home/jedixnavi/.local/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# MSE value of base model is 0.10613839386116722
# Features sorted by their score:
# [(0.2365, 'http://dbpedia.org/ontology/birthPlace?inv#count'), (0.117, 'http://dbpedia.org/ontology/areaTotal#1'), (0.1009, 'http://dbpedia.org/ontology/country#1@OTHER'), (0.0639, 'http://dbpedia.org/ontology/country#1@<http://dbpedia.org/resource/India>'), (0.0458, 'http://dbpedia.org/ontology/timeZone#1@<http://dbpedia.org/resource/China_Standard_Time>'), (0.0428, 'rel#count'), (0.0391, 'http://dbpedia.org/ontology/populationDensity#1'), (0.0329, 'http://dbpedia.org/ontology/elevation#1'), (0.0197, 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type#1@<http://dbpedia.org/ontology/City>'), (0.0191, 'http://dbpedia.org/ontology/utcOffset#count'), (0.017, 'http://dbpedia.org/ontology/country#1@<http://dbpedia.org/resource/Brazil>'), (0.0125, 'http://dbpedia.org/ontology/areaLand#1'), (0.0121, 'http://dbpedia.org/ontology/isPartOf#count'), (0.0115, 'http://dbpedia.org/ontology/city?inv#count'), (0.0095, 'http://dbpedia.org/ontology/country#1@<http://dbpedia.org/resource/Mexico>'), (0.0081, 'http://dbpedia.org/ontology/utcOffset#2@OTHER'), (0.0079, 'http://dbpedia.org/ontology/isPartOf?inv#count'), (0.0078, 'http://dbpedia.org/ontology/location?inv#count'), (0.0077, 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type#1@OTHER'), (0.0071, 'http://xmlns.com/foaf/0.1/name#count'), (0.0067, 'http://dbpedia.org/ontology/ground?inv#count'), (0.0066, 'http://dbpedia.org/ontology/headquarter?inv#count'), (0.0061, 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type#1@<http://dbpedia.org/ontology/Settlement>'), (0.0058, 'http://dbpedia.org/ontology/postalCode#count'), (0.0058, 'http://dbpedia.org/ontology/deathPlace?inv#count'), (0.0053, 'http://dbpedia.org/ontology/area#1'), (0.0048, 'http://dbpedia.org/ontology/utcOffset#1@"-5"'), (0.0042, 'http://xmlns.com/foaf/0.1/homepage#count'), (0.0042, 'http://dbpedia.org/ontology/maximumElevation#1'), (0.0041, 'http://dbpedia.org/ontology/type#count'), (0.0041, 'http://dbpedia.org/ontology/areaCode#count'), (0.0039, 'http://dbpedia.org/ontology/leaderTitle#count'), (0.0038, 'http://dbpedia.org/ontology/utcOffset#1@"+8"'), (0.0037, 'http://www.w3.org/2000/01/rdf-schema#seeAlso#count'), (0.0037, 'http://dbpedia.org/ontology/timeZone#count'), (0.0035, 'http://dbpedia.org/ontology/country#1@<http://dbpedia.org/resource/United_States>'), (0.0034, 'http://dbpedia.org/ontology/locationCity?inv#count'), (0.0029, 'http://dbpedia.org/ontology/populationDensity#count'), (0.0029, 'http://dbpedia.org/ontology/elevation#count'), (0.0029, 'http://dbpedia.org/ontology/areaLand#count'), (0.0028, 'http://dbpedia.org/ontology/residence?inv#count'), (0.0028, 'http://dbpedia.org/ontology/country#1@<http://dbpedia.org/resource/Ukraine>'), (0.0026, 'http://dbpedia.org/ontology/leaderName#count'), (0.0026, 'http://dbpedia.org/ontology/hometown?inv#count'), (0.0025, 'http://dbpedia.org/ontology/nearestCity?inv#count'), (0.0024, 'http://dbpedia.org/ontology/utcOffset#1@"+5:30"'), (0.0023, 'http://dbpedia.org/ontology/type#1@OTHER'), (0.0023, 'http://dbpedia.org/ontology/timeZone#1@OTHER'), (0.0023, 'http://dbpedia.org/ontology/country#count'), (0.0022, 'http://xmlns.com/foaf/0.1/nick#count'), (0.0022, 'http://dbpedia.org/ontology/region#count'), (0.0022, 'http://dbpedia.org/ontology/areaLand#2'), (0.0021, 'http://dbpedia.org/ontology/foundingDate#count'), (0.002, 'http://dbpedia.org/ontology/routeJunction?inv#count'), (0.0018, 'http://dbpedia.org/ontology/utcOffset#1@OTHER'), (0.0018, 'http://dbpedia.org/ontology/areaWater#1'), (0.0017, 'http://dbpedia.org/ontology/type#1@<http://dbpedia.org/resource/Prefecture-level_city>'), (0.0017, 'http://dbpedia.org/ontology/populationAsOf#count'), (0.0017, 'http://dbpedia.org/ontology/populationAsOf#1@"2008-06-30"^^<http://www.w3.org/2001/XMLSchema#date>'), (0.0016, 'http://dbpedia.org/ontology/timeZone#1@<http://dbpedia.org/resource/Central_European_Time>'), (0.0016, 'http://dbpedia.org/ontology/routeEnd?inv#count'), (0.0016, 'http://dbpedia.org/ontology/country#1@<http://dbpedia.org/resour ...

# %%
import skimage.filters

#Calculating a threshold value using Otsu's method used in image thresholding
f_new = np.array(features['http://dbpedia.org/ontology/birthPlace?inv#count'])
t = skimage.filters.threshold_otsu(f_new) #Otsu's method

#Data binning into 0's and 1's
c = (f_new >= t).astype(int) 
features['f_new'] = c

#Running model on new set of features
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.30, random_state=42)
rf_model.fit(X_train,y_train)
pred_y = rf_model.predict(X_test)
mse_score = mean_squared_error(y_test,pred_y)
print("MSE value of base model is",mse_score_old)
print("Updated MSE value is",mse_score)
# Out:
# MSE value of base model is 0.10613839386116722
# Updated MSE value is 0.1044993194622291
